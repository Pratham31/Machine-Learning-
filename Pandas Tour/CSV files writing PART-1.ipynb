# %%
import pandas as pd

# %% [markdown]
# # How to write csv files

# %%
pd.read_csv('D:\\Machine Learning\\data.csv')
# Out:
#    ID  class  study_hrs  sleeping_hrs  social_media  gaming  percent
# 0   1     10          2             9             3       5       50
# 1   2     10          6             8             2       0       80
# 2   3     10          3             8             2       4       60
# 3   4     11          0            10             1       5       45
# 4   5     11          4             7             2       0       75
# 5   6     11         10             7             0       0       96
# 6   7     12          4             6             0       0       80
# 7   8     12         10             6             2       0       90
# 8   9     12          2             8             2       4       60
# 9  10     12          6             9             1       0       85

# %% [markdown]
# # Every csv file is by default DataFrame..Here it is How?

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv')
df
# Out:
#    ID  class  study_hrs  sleeping_hrs  social_media  gaming  percent
# 0   1     10          2             9             3       5       50
# 1   2     10          6             8             2       0       80
# 2   3     10          3             8             2       4       60
# 3   4     11          0            10             1       5       45
# 4   5     11          4             7             2       0       75
# 5   6     11         10             7             0       0       96
# 6   7     12          4             6             0       0       80
# 7   8     12         10             6             2       0       90
# 8   9     12          2             8             2       4       60
# 9  10     12          6             9             1       0       85

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns #for getting names of columns
# Out:
# Index(['ID', 'class', 'study_hrs', 'sleeping_hrs', 'social_media', 'gaming',
#        'percent'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-412feca855b9> in <module>
# ----> 1 df.rows
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv',nrows=1) #for getting first row data
df
# Out:
#    ID  class  study_hrs  sleeping_hrs  social_media  gaming  percent
# 0   1     10          2             9             3       5       50

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv',usecols=[0,1]) #for getting first row data
df
# Out:
#    ID  class
# 0   1     10
# 1   2     10
# 2   3     10
# 3   4     11
# 4   5     11
# 5   6     11
# 6   7     12
# 7   8     12
# 8   9     12
# 9  10     12

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv',nrows=4) #for getting first row data
df
# Out:
#    ID  class  study_hrs  sleeping_hrs  social_media  gaming  percent
# 0   1     10          2             9             3       5       50
# 1   2     10          6             8             2       0       80
# 2   3     10          3             8             2       4       60
# 3   4     11          0            10             1       5       45

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv',index_col='ID') #for getting ID as index
df
# Out:
#     class  study_hrs  sleeping_hrs  social_media  gaming  percent
# ID
# 1      10          2             9             3       5       50
# 2      10          6             8             2       0       80
# 3      10          3             8             2       4       60
# 4      11          0            10             1       5       45
# 5      11          4             7             2       0       75
# 6      11         10             7             0       0       96
# 7      12          4             6             0       0       80
# 8      12         10             6             2       0       90
# 9      12          2             8             2       4       60
# 10     12          6             9             1       0       85

# %%
df=pd.read_csv('D:\\Machine Learning\\data.csv',index_col='percent') #for getting percent as index
df
# Out:
#          ID  class  study_hrs  sleeping_hrs  social_media  gaming
# percent
# 50        1     10          2             9             3       5
# 80        2     10          6             8             2       0
# 60        3     10          3             8             2       4
# 45        4     11          0            10             1       5
# 75        5     11          4             7             2       0
# 96        6     11         10             7             0       0
# 80        7     12          4             6             0       0
# 90        8     12         10             6             2       0
# 60        9     12          2             8             2       4
# 85       10     12          6             9             1       0
