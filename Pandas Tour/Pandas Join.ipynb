# %%
import pandas as pd

# %%
df1=pd.DataFrame({'A':[1,2,3,4,5],
                 'B':[10,20,30,40,50]})

# %%
df2=pd.DataFrame({'C':[111,222,333,444,555],
                 'D':[1111,2222,3333,4444,5555]})

# %%
df1
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
df2
# Out:
#      C     D
# 0  111  1111
# 1  222  2222
# 2  333  3333
# 3  444  4444
# 4  555  5555

# %%
display(df1,df2)
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50
#      C     D
# 0  111  1111
# 1  222  2222
# 2  333  3333
# 3  444  4444
# 4  555  5555

# %% [markdown]
# # join() function :

# %%
df1.join(df2)
# Out:
#    A   B    C     D
# 0  1  10  111  1111
# 1  2  20  222  2222
# 2  3  30  333  3333
# 3  4  40  444  4444
# 4  5  50  555  5555

# %%
df3=pd.DataFrame({'C':[1,2,3,4,5],
                 'D':[10,20,30,40,50]},index=['a','b','c','d','e'])
df3
# Out:
#    C   D
# a  1  10
# b  2  20
# c  3  30
# d  4  40
# e  5  50

# %%
df1
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
df2.join(df1,how='left')
# Out:
#      C     D  A   B
# 0  111  1111  1  10
# 1  222  2222  2  20
# 2  333  3333  3  30
# 3  444  4444  4  40
# 4  555  5555  5  50

# %%
df2.join(df1,how='right')
# Out:
#      C     D  A   B
# 0  111  1111  1  10
# 1  222  2222  2  20
# 2  333  3333  3  30
# 3  444  4444  4  40
# 4  555  5555  5  50

# %%
df1
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  4  40
# 4  5  50

# %%
df3
# Out:
#    C   D
# a  1  10
# b  2  20
# c  3  30
# d  4  40
# e  5  50

# %% [markdown]
# # If index is different -

# %%
df1.join(df3)
# Out:
#    A   B   C   D
# 0  1  10 NaN NaN
# 1  2  20 NaN NaN
# 2  3  30 NaN NaN
# 3  4  40 NaN NaN
# 4  5  50 NaN NaN
